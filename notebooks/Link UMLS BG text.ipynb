# %%
import pandas as pd

# %%
# !pip install elasticsearch
# Out:
# Requirement already satisfied: elasticsearch in /home/sylvia/anaconda3/lib/python3.8/site-packages (8.7.0)
# Requirement already satisfied: elastic-transport<9,>=8 in /home/sylvia/anaconda3/lib/python3.8/site-packages (from elasticsearch) (8.4.0)
# Requirement already satisfied: urllib3<2,>=1.26.2 in /home/sylvia/anaconda3/lib/python3.8/site-packages (from elastic-transport<9,>=8->elasticsearch) (1.26.4)
# Requirement already satisfied: certifi in /home/sylvia/anaconda3/lib/python3.8/site-packages (from elastic-transport<9,>=8->elasticsearch) (2020.12.5)
#
# [notice] A new release of pip is available: 23.1.2 -> 23.2.1
# [notice] To update, run: pip install --upgrade pip

# %%
from __future__ import unicode_literals
from elasticsearch import Elasticsearch

import json

def get_elastic():
    return Elasticsearch(
        [{'host': 'localhost', 'port': 9200, 'scheme': 'http'}], 
        timeout=30, 
        max_retries=1, 
        retry_on_timeout=False
        )

# logger = logging.getLogger(__name__)
# logging.basicConfig(level=logging.INFO)

def query_search(q_dic, index_name, n_search=1000, elastic=None):
    '''
    q_dic: query dictionary in Elastic format ready to search 
    index_name: index in Elastic where to search
    '''
    if elastic is None:
        elastic = get_elastic()
    #body = json.dumps(q_dic, ensure_ascii=False)
    search_result = elastic.search(index=index_name, body=q_dic, size=n_search, from_=0)

    return search_result

def result2list_unique(result_dict, field):
    lst = []
    if result_dict['hits']['total']['value'] > 0:
        for hit in result_dict['hits']['hits']:
            if hit['_source'][field] not in lst: 
                lst.append(hit['_source'][field])
    return lst

def result2list_(result_dict, field):
    lst = []
    if result_dict['hits']['total']['value'] > 0:
        for hit in result_dict['hits']['hits']:
            lst.append(hit['_source'][field])
    return lst


def get_umls2sab_query(source_id, target_sab, lang):
    '''
    source_id: UMLS ID (CUI) to search
    target_sab: ontology mapped to this ID
    '''
    q_dic = {
        "query": { 
            "bool": { 
            "must": [
                {"match": {"CODE": source_id}},
                {"match": {"SAB": target_sab}}, 
                {"match": {"LAT": lang}}
                ]
                    }
                }
            }
    return q_dic

def query_and_search(code, index): 
    result_list = []
    q_dic = get_umls2sab_query(code, 'SCTSPA', 'SPA')
    result = query_search(q_dic, index)
    if result['hits']['total']['value'] > 0:
        for hit in result['hits']['hits']: 
            result_list.append(hit['_source'])

    return result_list

def get_umlstext_query(term, index, lang):
    '''
    source_id: UMLS ID (CUI) to search
    target_sab: ontology mapped to this ID
    '''
    q_dic = {
        "query": { 
            "bool": { 
            "must": [
                {"match": {
                  "STR": term
                }}, 
                {"match": {"LAT": lang}}
                ]
                    }
                }
            }
    return q_dic

def query_and_search_text(term, index): 
    result_list = []
    q_dic = get_umlstext_query(term, 'UMLS', 'ENG')
    result = query_search(q_dic, index)
    if result['hits']['total']['value'] > 0:
        for hit in result['hits']['hits']: 
            result_list.append(hit['_source'])

    return result_list

# %%
with open("vicuna_links/bg_test_multi_conll_result_0813v113b.txt", "r") as file1:
    lines = file1.readlines()

# %%
lines[0:10]
# Out:
# ['дългогодишна B-MEDTERM\n',
#  'хипертония I-MEDTERM\n',
#  ', O\n',
#  'има O\n',
#  'често O\n',
#  'главоболие B-MEDTERM\n',
#  ', O\n',
#  'сърцебиене B-MEDTERM\n',
#  'и O\n',
#  'лесно O\n']

# %%
conll_entities = []
current_entity = ''
for line in lines:
    line = line.replace('\n', '')
    if len(line) > 0:
        line_parts = line.split(' ')
        if line_parts[1].startswith('B-'):
            if current_entity != '':
                conll_entities.append(current_entity)
            current_entity = str(line_parts[0])
        elif line_parts[1].startswith('I-'):
            current_entity += ' ' + str(line_parts[0])
        else:
            if current_entity != '':
                conll_entities.append(current_entity)
                current_entity = ''
    else:
        if current_entity != '':
            conll_entities.append(current_entity)
            current_entity = ''
                
if current_entity != '':
    conll_entities.append(current_entity)
    current_entity = ''

# %%
len(conll_entities)
# Out:
# 370

# %%
conll_entities[0:10]
# Out:
# ['дългогодишна хипертония',
#  'главоболие',
#  'сърцебиене',
#  'заморяване',
#  'стягане в сърдечната област',
#  'сърцебиене',
#  'гадене',
#  'карцином на простатата',
#  'сухота',
#  'сутрин']

# %%
import pandas as pd

df_terms = pd.read_csv('bg_test_0928v113b_llamaentities_nofuzzy_linked_sap.tsv', sep='\t', header=0)

# %%
df_terms.shape
# Out:
# (329, 9)

# %%
#df_terms['links'] = '' #df_terms['code']

# %%
pred_unique = set(df_terms['text_segment'].unique())

# %%
#true_unique = set(df_gold['span'].unique())

# %%
len(pred_unique.intersection(true_unique))
# Out:
# 119

# %%
len(true_unique)
# Out:
# 232

# %%
119/232
# Out:
# 0.5129310344827587

# %%
links = []
for index, row in df_terms.iterrows():
    results = query_and_search_text(row['translation'], 'umls')
    link = ''
    if len(results) > 0:        
        link = 'UMLS:' + results[0]['CUI']
    
    links.append(link)
# Out:
# /tmp/ipykernel_192/124867022.py:7: DeprecationWarning: The 'timeout' parameter is deprecated in favor of 'request_timeout'
#   return Elasticsearch(
# /tmp/ipykernel_192/124867022.py:25: DeprecationWarning: The 'body' parameter is deprecated and will be removed in a future version. Instead use individual parameters.
#   search_result = elastic.search(index=index_name, body=q_dic, size=n_search, from_=0)

# %%
#df_terms['links'] = links
df_terms['links'] = df_terms['code'] 
df_terms.head()
# Out:
#    document_id  sentence_id  doc_start_index  doc_end_index  \
# 0            0            0                0            239
# 1            0            0                0            239
# 2            0            0                0            239
# 3            0            0                0            239
# 4            0            0                0            239
#
#    sentence_entity_start  sentence_entity_end             text_segment  \
# 0                      0                   23  дългогодишна хипертония
# 1                     36                   46               главоболие
# 2                     49                   59               сърцебиене
# 3                    137                  147               сърцебиене
# 4                     62                   78         лесно заморяване
#
#               translation           code          links
# 0                headache  UMLS:C0018681  UMLS:C0018681
# 1            palpitations  UMLS:C0030252  UMLS:C0030252
# 2               dizziness  UMLS:C0042571  UMLS:C0042571
# 3  tightness in the chest  UMLS:C0232292  UMLS:C0232292
# 4                  nausea  UMLS:C0027497  UMLS:C0027497

# %%
df_test = df_terms

# %%
df_test['filename'] = ''
df_test['mark'] = 'T1'
df_test['label'] = 'ENFERMEDAD'
df_test['semantic_rel'] = 'EXACT'
df_test['off0'] = df_test['sentence_entity_start']
df_test['off1'] = df_test['sentence_entity_end']
df_test['span'] = df_test['text_segment']
df_test['code'] = df_test['links']

for index, row in df_test.iterrows():
    df_test.at[index, 'filename'] = str(row['document_id']) + '_' + str(row['sentence_id'])

# %%
df_test_new = df_test.drop(['document_id', 'sentence_id', 'doc_start_index', 'doc_end_index', 'sentence_entity_start', 'sentence_entity_end', 'text_segment', 'links'], axis=1)

# %%
df_test_new = df_test_new[['filename','mark','label','off0','off1',
                                           'span', 'code', 'semantic_rel']]

# %%
df_test_new[df_test_new['span'] == 'no-match'].index
df_test_new = df_test_new.drop(df_test_new[df_test_new['span'] == 'no-match'].index)

# %%
df_test_new['add'] = False
df_test_new['sort_column'] = df_test_new['span'].str.len()
df_test_new = df_test_new.sort_values(by=['filename', 'sort_column'], ascending=False)

# %%
df_test_groups = df_test_new.groupby(by=["filename"])

for group in df_test_groups:
    added_indices = []
    for index, row in group[1].iterrows():
        if row['off0'] not in added_indices and row['off1'] not in added_indices:
            added_indices.extend(range(row['off0'], row['off1']))
            df_test_new.at[index, 'add'] = True

# %%
df_test_new = df_test_new[df_test_new['add']]
df_test_new = df_test_new.sort_values(by=['filename', 'off0', 'off1'])
df_test_new = df_test_new[['filename','mark','label','off0','off1',
                                           'span', 'code', 'semantic_rel']]
df_test_new.head()
# Out:
#   filename mark       label  off0  off1                         span  \
# 0      0_0   T1  ENFERMEDAD     0    23      дългогодишна хипертония
# 1      0_0   T1  ENFERMEDAD    36    46                   главоболие
# 2      0_0   T1  ENFERMEDAD    49    59                   сърцебиене
# 4      0_0   T1  ENFERMEDAD    62    78             лесно заморяване
# 5      0_0   T1  ENFERMEDAD   107   134  стягане в сърдечната област
#
#             code semantic_rel
# 0  UMLS:C0018681        EXACT
# 1  UMLS:C0030252        EXACT
# 2  UMLS:C0042571        EXACT
# 4  UMLS:C0027497        EXACT
# 5  UMLS:C0376358        EXACT

# %%
for index, row in df_test_new.iterrows():
    if row['span'].endswith('.') or row['span'].endswith(','):
        df_test_new.at[index, 'span'] = row['span'][0:-1]
        df_test_new.at[index, 'off1'] = row['off1']-1

# %%
df_test_new.shape
# Out:
# (306, 8)

# %%
df_test_new.to_csv('vicuna_links/distemist_evaluation_library/toy-data/subtask-linking/bg_test_entities_llama_sap_linked.tsv', sep='\t', index=False)

# %%
df_gold = pd.read_csv('bg_gold_standard_entities-translated.tsv', sep='\t', header=0)
#df_gold = pd.read_csv('bg_gold_standard_entities.tsv', sep='\t', header=0)
df_gold.head()
# Out:
#    filename                         span  off0  off1  \
# 0         0      дългогодишна хипертония     0    23
# 1         0             често главоболие    30    46
# 2         0                   сърцебиене    49    59
# 3         0             лесно заморяване    62    78
# 4         0  стягане в сърдечната област   107   134
#
#                     translation  code
# 0   long -standing hypertension   NaN
# 1             frequent headache   NaN
# 2                  palpitations   NaN
# 3                          ease   NaN
# 4  tightening in the heart area   NaN

# %%
df_gold.shape
# Out:
# (305, 6)

# %%
df_gold_manaul.shape
# Out:
# (305, 8)

# %%
for index, row in df_gold_manaul.iterrows():    
    df_gold.at[index, 'off0'] = row['off0']
    df_gold.at[index, 'off1'] = row['off1']
    
df_gold.head()
# Out:
#    filename                         span  off0  off1  \
# 0         0      дългогодишна хипертония     0    23
# 1         0             често главоболие    30    46
# 2         0                   сърцебиене    49    59
# 3         0             лесно заморяване    62    78
# 4         0  стягане в сърдечната област   107   134
#
#                     translation  code
# 0   long -standing hypertension   NaN
# 1             frequent headache   NaN
# 2                  palpitations   NaN
# 3                          ease   NaN
# 4  tightening in the heart area   NaN

# %%
links = []
texts = []
for index, row in df_gold.iterrows():
    results = query_and_search_text(row['translation'], 'umls')
    link = ''
    text = ''
    if len(results) > 0:        
        link = 'UMLS:' + results[0]['CUI']
        text = results[0]['STR']
    
    links.append(link)
    texts.append(text)
# Out:
# /tmp/ipykernel_385/124867022.py:7: DeprecationWarning: The 'timeout' parameter is deprecated in favor of 'request_timeout'
#   return Elasticsearch(
# /tmp/ipykernel_385/124867022.py:25: DeprecationWarning: The 'body' parameter is deprecated and will be removed in a future version. Instead use individual parameters.
#   search_result = elastic.search(index=index_name, body=q_dic, size=n_search, from_=0)

# %%
df_gold['code'] = links
df_gold['code_text'] = texts
df_gold.head()
# Out:
#    filename                         span  off0  off1  \
# 0         0      дългогодишна хипертония     0    23
# 1         0             често главоболие    30    46
# 2         0                   сърцебиене    49    59
# 3         0             лесно заморяване    62    78
# 4         0  стягане в сърдечната област   107   134
#
#                     translation           code             code_text
# 0   long -standing hypertension  UMLS:C0444344  Stride long-standing
# 1             frequent headache  UMLS:C0948396     Frequent headache
# 2                  palpitations  UMLS:C0030252          Palpitations
# 3                          ease  UMLS:C1331418                  Ease
# 4  tightening in the heart area  UMLS:C0423604       Tightening pain

# %%
df_gold.to_csv('bg_gold_standard_entities-translated_codes.tsv', sep='\t', index=False)

# %%
df_gold = pd.read_csv('bg_gold_standard_entities-manual_translated.tsv', sep='\t', header=0)
#df_gold = pd.read_csv('bg_gold_standard_entities-manual.tsv', sep='\t', header=0)

df_gold.head(30)
# Out:
#    filename mark       label  off0  off1  \
# 0       0_0   T1  ENFERMEDAD     0    23
# 1       0_0   T1  ENFERMEDAD    30    46
# 2       0_0   T1  ENFERMEDAD    49    59
# 3       0_0   T1  ENFERMEDAD    62    78
# 4       0_0   T1  ENFERMEDAD   107   134
# 5       0_0   T1  ENFERMEDAD   137   147
# 6       0_0   T1  ENFERMEDAD   150   156
# 7       0_0   T1  ENFERMEDAD   167   189
# 8       0_0   T1  ENFERMEDAD   224   236
# 9      11_0   T1  ENFERMEDAD     0    14
# 10     11_0   T1  ENFERMEDAD    75    98
# 11     11_0   T1  ENFERMEDAD   101   127
# 12     11_0   T1  ENFERMEDAD   151   167
# 13     11_0   T1  ENFERMEDAD   224   250
# 14     11_0   T1  ENFERMEDAD   321   346
# 15     11_0   T1  ENFERMEDAD   374   401
# 16     11_0   T1  ENFERMEDAD   430   440
# 17     11_0   T1  ENFERMEDAD   443   450
# 18     11_0   T1  ENFERMEDAD   453   470
# 19     11_0   T1  ENFERMEDAD   489   540
# 20     11_0   T1  ENFERMEDAD   543   559
# 21     11_0   T1  ENFERMEDAD   562   564
# 22     11_0   T1  ENFERMEDAD   567   573
# 23     11_0   T1  ENFERMEDAD   577   592
# 24     11_0   T1  ENFERMEDAD   595   602
# 25     11_0   T1  ENFERMEDAD   607   609
# 26     12_0   T1  ENFERMEDAD    37    57
# 27     12_0   T1  ENFERMEDAD    90   102
# 28     12_0   T1  ENFERMEDAD   105   116
# 29     12_0   T1  ENFERMEDAD   146   156
#
#                                                  span      true_code  \
# 0                             дългогодишна хипертония  UMLS:C0020538
# 1                                    често главоболие  UMLS:C0948396
# 2                                          сърцебиене  UMLS:C0030252
# 3                                    лесно заморяване  UMLS:C1331418
# 4                         стягане в сърдечната област  UMLS:C0232292
# 5                                          сърцебиене  UMLS:C0030252
# 6                                              гадене  UMLS:C0027497
# 7                              карцином на простатата  UMLS:C0496923
# 8                                        химиотерапия  UMLS:C0392920
# 9                                      захарен диабет  UMLS:C0011847
# 10                            диабетна полиневропатия  UMLS:C0271680
# 11                         тежка болкова симптоматика  UMLS:C0278140
# 12                                   арт . хипертония  UMLS:C0020538
# 13                         чести стенокардни пристъпи  UMLS:C0002962
# 14                          стеноза на аортната клапа  UMLS:C0003507
# 15                        генерализирана остеоартроза  UMLS:C1384584
# 16                                         гр . стълб  UMLS:C0037925
# 17                                            коленни  UMLS:C0022742
# 18                                  тазобедрени стави  UMLS:C0019558
# 19  рецидивираща уролитиаза/двукратна уретеролитот...  UMLS:C0750009
# 20                                   хр . пиелонефрит  UMLS:C0085697
# 21                                                 фа  UMLS:C0015625
# 22                                             сестра  UMLS:C1546515
# 23                                    инсулинолечение  UMLS:C0745343
# 24                                            чичовци  UMLS:C2318681
# 25                                                 зд  UMLS:C0011849
# 26                               карцином на бял дроб  UMLS:C0684249
# 27                                       химиотерапия  UMLS:C0392920
# 28                                        лъчелечение  UMLS:C0851346
# 29                                         главоболие  UMLS:C0018681
#
#    semantic_rel                                      translation
# 0         EXACT                      long -standing hypertension
# 1         EXACT                                frequent headache
# 2         EXACT                                     palpitations
# 3         EXACT                                             ease
# 4         EXACT                     tightening in the heart area
# 5         EXACT                                     palpitations
# 6         EXACT                                           nausea
# 7         EXACT                                         prostate
# 8         EXACT                                     chemotherapy
# 9         EXACT                                         diabetes
# 10        EXACT                          diabetic polyneuropathy
# 11        EXACT                             severe pain symptoms
# 12        EXACT                                Art. hypertension
# 13        EXACT                                  frequent angina
# 14        EXACT                     stenosis of the aortic valve
# 15        EXACT                       generalized osteoarthrosis
# 16        EXACT                                  city ​​. pillar
# 17        EXACT                                             knee
# 18        EXACT                                       hip joints
# 19        EXACT  Recurrent urolithiasis/double ureterolithotomy/
# 20        EXACT                               Hr. pyelonephritis
# 21        EXACT                                               fa
# 22        EXACT                                           sister
# 23        EXACT                                insulin treatment
# 24        EXACT                                           uncles
# 25        EXACT                                              Act
# 26        EXACT                                   lung carcinoma
# 27        EXACT                                     chemotherapy
# 28        EXACT                                        radiation
# 29        EXACT                                         headache

# %%
df_gold = df_gold.sort_values(by=['filename', 'off0', 'off1'])

# %%
df_gold.shape
# Out:
# (305, 9)

# %%
df_gold_manaul = df_gold_manaul.sort_values(by=['filename', 'off0', 'off1'])

# %%
df_gold_manaul.shape
# Out:
# (305, 8)

# %%
df_gold_manaul.head(30)
# Out:
#     filename mark       label  off0  off1  \
# 0        0_0   T1  ENFERMEDAD     0    23
# 1        0_0   T1  ENFERMEDAD    30    46
# 2        0_0   T1  ENFERMEDAD    49    59
# 3        0_0   T1  ENFERMEDAD    62    78
# 4        0_0   T1  ENFERMEDAD   107   134
# 5        0_0   T1  ENFERMEDAD   137   147
# 6        0_0   T1  ENFERMEDAD   150   156
# 7        0_0   T1  ENFERMEDAD   167   189
# 8        0_0   T1  ENFERMEDAD   224   236
# 115     10_0   T1  ENFERMEDAD    14    24
# 116     10_0   T1  ENFERMEDAD    27    40
# 117     10_0   T1  ENFERMEDAD    43    54
# 118     10_0   T1  ENFERMEDAD    57    73
# 119     10_0   T1  ENFERMEDAD    76    81
# 120     10_0   T1  ENFERMEDAD    84    89
# 121     10_0   T1  ENFERMEDAD    92   115
# 122     10_0   T1  ENFERMEDAD   118   156
# 123     10_0   T1  ENFERMEDAD   171   186
# 124     10_0   T1  ENFERMEDAD   191   197
# 125     10_0   T1  ENFERMEDAD   200   206
# 126     10_0   T1  ENFERMEDAD   209   222
# 127     10_0   T1  ENFERMEDAD   239   272
# 128     10_0   T1  ENFERMEDAD   275   296
# 129     10_0   T1  ENFERMEDAD   349   397
# 130     10_0   T1  ENFERMEDAD   414   419
# 131     11_0   T1  ENFERMEDAD    21    35
# 132     11_0   T1  ENFERMEDAD    96   119
# 133     11_0   T1  ENFERMEDAD   122   148
# 134     11_0   T1  ENFERMEDAD   172   188
# 135     11_0   T1  ENFERMEDAD   245   271
#
#                                                  span code semantic_rel
# 0                             дългогодишна хипертония             EXACT
# 1                                    често главоболие             EXACT
# 2                                          сърцебиене             EXACT
# 3                                    лесно заморяване             EXACT
# 4                         стягане в сърдечната област             EXACT
# 5                                          сърцебиене             EXACT
# 6                                              гадене             EXACT
# 7                              карцином на простатата             EXACT
# 8                                        химиотерапия             EXACT
# 115                                        главоболие             EXACT
# 116                                     виене на свят             EXACT
# 117                                       лесна умора             EXACT
# 118                                  тежест в гърдите             EXACT
# 119                                             задух             EXACT
# 120                                             жажда             EXACT
# 121                           болки в дясно подребрие             EXACT
# 122            ирадииращи към кръста и дясната плешка             EXACT
# 123                                   често уриниране             EXACT
# 124                                            парене             EXACT
# 125                                            жежене             EXACT
# 126                                     неспокоен сьн             EXACT
# 127                 подуване на лимфен възел на шията             EXACT
# 128                             болезнен при палпация             EXACT
# 129  наранява в областта на дясната тазобедрена става             EXACT
# 130                                             болка             EXACT
# 131                                    захарен диабет             EXACT
# 132                           диабетна полиневропатия             EXACT
# 133                        тежка болкова симптоматика             EXACT
# 134                                  арт . хипертония             EXACT
# 135                        чести стенокардни пристъпи             EXACT

# %%
df_gold.head(30)
# Out:
#     filename mark       label  off0  off1  \
# 0        0_0   T1  ENFERMEDAD     0    23
# 1        0_0   T1  ENFERMEDAD    30    46
# 2        0_0   T1  ENFERMEDAD    49    59
# 3        0_0   T1  ENFERMEDAD    62    78
# 4        0_0   T1  ENFERMEDAD   107   134
# 5        0_0   T1  ENFERMEDAD   137   147
# 6        0_0   T1  ENFERMEDAD   150   156
# 7        0_0   T1  ENFERMEDAD   167   189
# 8        0_0   T1  ENFERMEDAD   224   236
# 84      10_0   T1  ENFERMEDAD    14    24
# 85      10_0   T1  ENFERMEDAD    27    40
# 87      10_0   T1  ENFERMEDAD    43    54
# 88      10_0   T1  ENFERMEDAD    57    73
# 89      10_0   T1  ENFERMEDAD    76    81
# 90      10_0   T1  ENFERMEDAD    84    89
# 92      10_0   T1  ENFERMEDAD    92   115
# 94      10_0   T1  ENFERMEDAD   118   156
# 98      10_0   T1  ENFERMEDAD   171   186
# 99      10_0   T1  ENFERMEDAD   191   197
# 100     10_0   T1  ENFERMEDAD   200   206
# 101     10_0   T1  ENFERMEDAD   209   222
# 102     10_0   T1  ENFERMEDAD   239   272
# 104     10_0   T1  ENFERMEDAD   275   296
# 108     10_0   T1  ENFERMEDAD   349   397
# 109     10_0   T1  ENFERMEDAD   414   419
# 9       11_0   T1  ENFERMEDAD     0    14
# 10      11_0   T1  ENFERMEDAD    75    98
# 11      11_0   T1  ENFERMEDAD   101   127
# 12      11_0   T1  ENFERMEDAD   151   167
# 13      11_0   T1  ENFERMEDAD   224   250
#
#                                                  span      true_code  \
# 0                             дългогодишна хипертония  UMLS:C0020538
# 1                                    често главоболие  UMLS:C0948396
# 2                                          сърцебиене  UMLS:C0030252
# 3                                    лесно заморяване  UMLS:C1331418
# 4                         стягане в сърдечната област  UMLS:C0232292
# 5                                          сърцебиене  UMLS:C0030252
# 6                                              гадене  UMLS:C0027497
# 7                              карцином на простатата  UMLS:C0496923
# 8                                        химиотерапия  UMLS:C0392920
# 84                                         главоболие  UMLS:C0018681
# 85                                      виене на свят  UMLS:C0012833
# 87                                        лесна умора  UMLS:C0015672
# 88                                   тежест в гърдите  UMLS:C0742339
# 89                                              задух  UMLS:C0013404
# 90                                              жажда  UMLS:C0039971
# 92                            болки в дясно подребрие  UMLS:C0857180
# 94             ирадииращи към кръста и дясната плешка  UMLS:C0948843
# 98                                    често уриниране  UMLS:C0042023
# 99                                             парене  UMLS:C0175627
# 100                                            жежене  UMLS:C0231530
# 101                                     неспокоен сьн  UMLS:C0085631
# 102                 подуване на лимфен възел на шията  UMLS:C0497156
# 104                             болезнен при палпация  UMLS:C0030247
# 108  наранява в областта на дясната тазобедрена става  UMLS:C4281103
# 109                                             болка  UMLS:C0030193
# 9                                      захарен диабет  UMLS:C0011847
# 10                            диабетна полиневропатия  UMLS:C0271680
# 11                         тежка болкова симптоматика  UMLS:C0278140
# 12                                   арт . хипертония  UMLS:C0020538
# 13                         чести стенокардни пристъпи  UMLS:C0002962
#
#     semantic_rel                                     translation
# 0          EXACT                     long -standing hypertension
# 1          EXACT                               frequent headache
# 2          EXACT                                    palpitations
# 3          EXACT                                            ease
# 4          EXACT                    tightening in the heart area
# 5          EXACT                                    palpitations
# 6          EXACT                                          nausea
# 7          EXACT                                        prostate
# 8          EXACT                                    chemotherapy
# 84         EXACT                                        headache
# 85         EXACT                                       dizziness
# 87         EXACT                                 ease of fatigue
# 88         EXACT                                           chest
# 89         EXACT                             shortness of breath
# 90         EXACT                                          thirst
# 92         EXACT                              right -handed pain
# 94         EXACT     irradiating to the waist and right shoulder
# 98         EXACT                              frequent urination
# 99         EXACT                                         burning
# 100        EXACT                                            jerk
# 101        EXACT                                        restless
# 102        EXACT          swelling of the lymph node of the neck
# 104        EXACT                                       palpation
# 108        EXACT  injured in the area of ​​the right hip becomes
# 109        EXACT                                            pain
# 9          EXACT                                        diabetes
# 10         EXACT                         diabetic polyneuropathy
# 11         EXACT                            severe pain symptoms
# 12         EXACT                               Art. hypertension
# 13         EXACT                                 frequent angina

# %%
#for index, row in df_gold.iterrows():    
#    filter_file = df_gold_manaul['filename'] == row['filename']
#    filter_span = df_gold_manaul['span'] == row['span']
#    true_rows = df_gold_manaul[filter_file & filter_span]
    
#    if true_rows.shape[0] == 0:
#        print(row)
#    true_row = true_rows.iloc[0]
#    df_gold.at[index, 'off0'] = true_row['off0']
#    df_gold.at[index, 'off1'] = true_row['off1']
    
#df_gold.head(30)

# %%
#df_gold['filename'] = df_gold['filename'].astype(str)

# %%
#for index, row in df_gold.iterrows():
#    new_val = row['filename'] + '_0'
#    df_gold.at[index, 'filename'] = new_val

# %%
# !pip install Levenshtein
# Out:
# Requirement already satisfied: Levenshtein in /home/sylvia/anaconda3/lib/python3.8/site-packages (0.21.1)
# Requirement already satisfied: rapidfuzz<4.0.0,>=2.3.0 in /home/sylvia/anaconda3/lib/python3.8/site-packages (from Levenshtein) (3.2.0)
#
# [notice] A new release of pip is available: 23.1.2 -> 23.2.1
# [notice] To update, run: pip install --upgrade pip

# %%
import Levenshtein

def select_best_candidate(text, results):
    max_ratio = 0
    max_candidate = results[0]['CUI']
    max_candidate_text = results[0]['STR']
    
    for result in results:
        ratio = Levenshtein.ratio(text, result['STR'])
        
        if ratio > max_ratio:
            max_ratio = ratio
            max_candidate = result['CUI']
            max_candidate_text = result['STR']
            
    return max_candidate, max_candidate_text

# %%
links = []
texts = []
for index, row in df_gold.iterrows():
    results = query_and_search_text(row['translation'], 'umls')
    link = ''
    text = ''
    if len(results) > 0:        
        #link = 'UMLS:' + results[0]['CUI']
        link, text = select_best_candidate(row['translation'], results)
        link = 'UMLS:' + link
        #text = results[0]['STR']
    
    links.append(link)
    texts.append(text)

# %%
df_gold['code'] = links
df_gold['code_text'] = texts

# %%
df_gold['mark'] = 'T1'
df_gold['label'] = 'ENFERMEDAD'
df_gold['semantic_rel'] = 'EXACT'

# %%
df_gold = df_gold[['filename', 'mark', 'label', 'off0', 'off1', 'span', 'code', 'semantic_rel']]

# %%
df_gold = df_gold.sort_values(by=['filename', 'off0', 'off1'])

# %%
df_gold.head(30)
# Out:
#     filename mark       label  off0  off1  \
# 0        0_0   T1  ENFERMEDAD     0    23
# 1        0_0   T1  ENFERMEDAD    30    46
# 2        0_0   T1  ENFERMEDAD    49    59
# 3        0_0   T1  ENFERMEDAD    62    78
# 4        0_0   T1  ENFERMEDAD   107   134
# 5        0_0   T1  ENFERMEDAD   137   147
# 6        0_0   T1  ENFERMEDAD   150   156
# 7        0_0   T1  ENFERMEDAD   167   189
# 8        0_0   T1  ENFERMEDAD   224   236
# 84      10_0   T1  ENFERMEDAD    14    24
# 85      10_0   T1  ENFERMEDAD    27    40
# 87      10_0   T1  ENFERMEDAD    43    54
# 88      10_0   T1  ENFERMEDAD    57    73
# 89      10_0   T1  ENFERMEDAD    76    81
# 90      10_0   T1  ENFERMEDAD    84    89
# 92      10_0   T1  ENFERMEDAD    92   115
# 94      10_0   T1  ENFERMEDAD   118   156
# 98      10_0   T1  ENFERMEDAD   171   186
# 99      10_0   T1  ENFERMEDAD   191   197
# 100     10_0   T1  ENFERMEDAD   200   206
# 101     10_0   T1  ENFERMEDAD   209   222
# 102     10_0   T1  ENFERMEDAD   239   272
# 104     10_0   T1  ENFERMEDAD   275   296
# 108     10_0   T1  ENFERMEDAD   349   397
# 109     10_0   T1  ENFERMEDAD   414   419
# 9       11_0   T1  ENFERMEDAD     0    14
# 10      11_0   T1  ENFERMEDAD    75    98
# 11      11_0   T1  ENFERMEDAD   101   127
# 12      11_0   T1  ENFERMEDAD   151   167
# 13      11_0   T1  ENFERMEDAD   224   250
#
#                                                  span code semantic_rel
# 0                             дългогодишна хипертония             EXACT
# 1                                    често главоболие             EXACT
# 2                                          сърцебиене             EXACT
# 3                                    лесно заморяване             EXACT
# 4                         стягане в сърдечната област             EXACT
# 5                                          сърцебиене             EXACT
# 6                                              гадене             EXACT
# 7                              карцином на простатата             EXACT
# 8                                        химиотерапия             EXACT
# 84                                         главоболие             EXACT
# 85                                      виене на свят             EXACT
# 87                                        лесна умора             EXACT
# 88                                   тежест в гърдите             EXACT
# 89                                              задух             EXACT
# 90                                              жажда             EXACT
# 92                            болки в дясно подребрие             EXACT
# 94             ирадииращи към кръста и дясната плешка             EXACT
# 98                                    често уриниране             EXACT
# 99                                             парене             EXACT
# 100                                            жежене             EXACT
# 101                                     неспокоен сьн             EXACT
# 102                 подуване на лимфен възел на шията             EXACT
# 104                             болезнен при палпация             EXACT
# 108  наранява в областта на дясната тазобедрена става             EXACT
# 109                                             болка             EXACT
# 9                                      захарен диабет             EXACT
# 10                            диабетна полиневропатия             EXACT
# 11                         тежка болкова симптоматика             EXACT
# 12                                   арт . хипертония             EXACT
# 13                         чести стенокардни пристъпи             EXACT

# %%
#df_gold.to_csv('bg_gold_standard_entities-manual_norm.tsv', sep='\t', index=False)
df_gold.to_csv('bg_gold_standard_entities-predicted_lev_norm.tsv', sep='\t', index=False)

# %%
#df_gold_manaul = pd.read_csv('bg_text_manual.csv', header=0)

df_gold_manaul = pd.read_csv('bg_gold_standard_entities.tsv', sep='\t', header=0)
df_gold_manaul.head()
# Out:
#    filename                         span  off0  off1
# 0         0      дългогодишна хипертония     0    23
# 1         0             често главоболие    30    46
# 2         0                   сърцебиене    49    59
# 3         0             лесно заморяване    62    78
# 4         0  стягане в сърдечната област   107   134

# %%
#df_gold_manaul['span'] = list(df_gold['span'].values)

# %%
#df_gold_manaul = df_gold_manaul[['filename', 'span', 'off0', 'off1', 'true_code']]

# %%
#df_gold_manaul = df_gold_manaul.rename(columns={"true_code": "code"})

# %%
df_gold_manaul.head()
#filename	mark	label	off0	off1	span	code	semantic_rel
# Out:
#    filename                         span  off0  off1
# 0         0      дългогодишна хипертония     0    23
# 1         0             често главоболие    30    46
# 2         0                   сърцебиене    49    59
# 3         0             лесно заморяване    62    78
# 4         0  стягане в сърдечната област   107   134

# %%
df_gold_manaul['mark'] = 'T1'
df_gold_manaul['label'] = 'ENFERMEDAD'
df_gold_manaul['semantic_rel'] = 'EXACT'

# %%
df_gold_manaul['code'] = ''

# %%
df_gold_manaul = df_gold_manaul[['filename', 'mark', 'label', 'off0', 'off1', 'span', 'code', 'semantic_rel']]

# %%
df_gold_manaul['filename'] = df_gold_manaul['filename'].astype(str)

# %%
for index, row in df_gold_manaul.iterrows():
    #new_val = row['filename'].replace('0', '') + '0'
    #if new_val.startswith('_'):
    #    new_val = '0' + new_val
    new_val = row['filename'] + '_0'
    df_gold_manaul.at[index, 'filename'] = new_val

# %%
df_gold_manaul = df_gold_manaul.sort_values(by=['filename', 'off0', 'off1'])

# %%
df_gold_manaul.head(30)
# Out:
#     filename mark       label  off0  off1  \
# 0        0_0   T1  ENFERMEDAD     0    23
# 1        0_0   T1  ENFERMEDAD    30    46
# 2        0_0   T1  ENFERMEDAD    49    59
# 3        0_0   T1  ENFERMEDAD    62    78
# 4        0_0   T1  ENFERMEDAD   107   134
# 5        0_0   T1  ENFERMEDAD   137   147
# 6        0_0   T1  ENFERMEDAD   150   156
# 7        0_0   T1  ENFERMEDAD   167   189
# 8        0_0   T1  ENFERMEDAD   224   236
# 115     10_0   T1  ENFERMEDAD    14    24
# 116     10_0   T1  ENFERMEDAD    27    40
# 117     10_0   T1  ENFERMEDAD    43    54
# 118     10_0   T1  ENFERMEDAD    57    73
# 119     10_0   T1  ENFERMEDAD    76    81
# 120     10_0   T1  ENFERMEDAD    84    89
# 121     10_0   T1  ENFERMEDAD    92   115
# 122     10_0   T1  ENFERMEDAD   118   156
# 123     10_0   T1  ENFERMEDAD   171   186
# 124     10_0   T1  ENFERMEDAD   191   197
# 125     10_0   T1  ENFERMEDAD   200   206
# 126     10_0   T1  ENFERMEDAD   209   222
# 127     10_0   T1  ENFERMEDAD   239   272
# 128     10_0   T1  ENFERMEDAD   275   296
# 129     10_0   T1  ENFERMEDAD   349   397
# 130     10_0   T1  ENFERMEDAD   414   419
# 131     11_0   T1  ENFERMEDAD    21    35
# 132     11_0   T1  ENFERMEDAD    96   119
# 133     11_0   T1  ENFERMEDAD   122   148
# 134     11_0   T1  ENFERMEDAD   172   188
# 135     11_0   T1  ENFERMEDAD   245   271
#
#                                                  span code semantic_rel
# 0                             дългогодишна хипертония             EXACT
# 1                                    често главоболие             EXACT
# 2                                          сърцебиене             EXACT
# 3                                    лесно заморяване             EXACT
# 4                         стягане в сърдечната област             EXACT
# 5                                          сърцебиене             EXACT
# 6                                              гадене             EXACT
# 7                              карцином на простатата             EXACT
# 8                                        химиотерапия             EXACT
# 115                                        главоболие             EXACT
# 116                                     виене на свят             EXACT
# 117                                       лесна умора             EXACT
# 118                                  тежест в гърдите             EXACT
# 119                                             задух             EXACT
# 120                                             жажда             EXACT
# 121                           болки в дясно подребрие             EXACT
# 122            ирадииращи към кръста и дясната плешка             EXACT
# 123                                   често уриниране             EXACT
# 124                                            парене             EXACT
# 125                                            жежене             EXACT
# 126                                     неспокоен сьн             EXACT
# 127                 подуване на лимфен възел на шията             EXACT
# 128                             болезнен при палпация             EXACT
# 129  наранява в областта на дясната тазобедрена става             EXACT
# 130                                             болка             EXACT
# 131                                    захарен диабет             EXACT
# 132                           диабетна полиневропатия             EXACT
# 133                        тежка болкова симптоматика             EXACT
# 134                                  арт . хипертония             EXACT
# 135                        чести стенокардни пристъпи             EXACT

# %%
df_gold_manaul.to_csv('bg_gold_standard_entities-manual_ner.tsv', sep='\t', index=False)

# %%
df_gold_manual_norm = pd.read_csv('bg_gold_standard_entities-manual_norm.tsv', sep='\t', header=0)
df_gold_manual_norm.head()
# Out:
#   filename mark       label  off0  off1                     span  \
# 0      0_0   T1  ENFERMEDAD     0    23  дългогодишна хипертония
# 1      0_0   T1  ENFERMEDAD    30    46         често главоболие
# 2      0_0   T1  ENFERMEDAD    49    59               сърцебиене
# 3      0_0   T1  ENFERMEDAD    49    59               сърцебиене
# 4      0_0   T1  ENFERMEDAD    62    78         лесно заморяване
#
#             code semantic_rel
# 0  UMLS:C0020538        EXACT
# 1  UMLS:C0948396        EXACT
# 2  UMLS:C0030252        EXACT
# 3  UMLS:C0030252        EXACT
# 4  UMLS:C1331418        EXACT

# %%
df_gold_pred_norm = pd.read_csv('vicuna_links/distemist_evaluation_library/toy-data/subtask-linking/bg_gold_standard_entities-predicted_lev_norm.tsv', sep='\t', header=0)
df_gold_pred_norm.head()
# Out:
#   filename mark       label  off0  off1                         span  \
# 0      0_0   T1  ENFERMEDAD     0    23      дългогодишна хипертония
# 1      0_0   T1  ENFERMEDAD    30    46             често главоболие
# 2      0_0   T1  ENFERMEDAD    49    59                   сърцебиене
# 3      0_0   T1  ENFERMEDAD    62    78             лесно заморяване
# 4      0_0   T1  ENFERMEDAD   107   134  стягане в сърдечната област
#
#             code semantic_rel
# 0  UMLS:C0597290        EXACT
# 1  UMLS:C0948396        EXACT
# 2  UMLS:C0030252        EXACT
# 3  UMLS:C1331418        EXACT
# 4  UMLS:C0011974        EXACT

# %%
df_gold_pred_norm['off0'] = df_gold_manual_norm['off0']
df_gold_pred_norm['off1'] = df_gold_manual_norm['off1']

# %%
df_gold_pred_norm.head()
# Out:
#   filename mark       label  off0  off1                         span  \
# 0      0_0   T1  ENFERMEDAD     0    23      дългогодишна хипертония
# 1      0_0   T1  ENFERMEDAD    30    46             често главоболие
# 2      0_0   T1  ENFERMEDAD    49    59                   сърцебиене
# 3      0_0   T1  ENFERMEDAD    49    59             лесно заморяване
# 4      0_0   T1  ENFERMEDAD    62    78  стягане в сърдечната област
#
#             code semantic_rel
# 0  UMLS:C0597290        EXACT
# 1  UMLS:C0948396        EXACT
# 2  UMLS:C0030252        EXACT
# 3  UMLS:C1331418        EXACT
# 4  UMLS:C0011974        EXACT

# %%
df_gold_pred_norm.to_csv('vicuna_links/distemist_evaluation_library/toy-data/subtask-linking/bg_gold_standard_entities-predicted_lev_norm.tsv', sep='\t', index=False)

# %%
df_pred_sap = pd.read_csv('vicuna_links/distemist_evaluation_library/toy-data/subtask-linking/bg_test_entities_sap_link.tsv', sep='\t', header=0)

# %%
df_pred_sap.head(50)
# Out:
#    filename mark       label  off0  off1  \
# 0       0_0   T1  ENFERMEDAD     0    23
# 1       0_0   T1  ENFERMEDAD    36    46
# 2       0_0   T1  ENFERMEDAD    49    59
# 3       0_0   T1  ENFERMEDAD    68    78
# 4       0_0   T1  ENFERMEDAD   107   134
# 5       0_0   T1  ENFERMEDAD   137   147
# 6       0_0   T1  ENFERMEDAD   150   156
# 7       0_0   T1  ENFERMEDAD   167   189
# 8      10_0   T1  ENFERMEDAD    14    24
# 9      10_0   T1  ENFERMEDAD    27    40
# 10     10_0   T1  ENFERMEDAD    43    54
# 11     10_0   T1  ENFERMEDAD    57    73
# 12     10_0   T1  ENFERMEDAD    76    81
# 13     10_0   T1  ENFERMEDAD    84    89
# 14     10_0   T1  ENFERMEDAD    92   115
# 15     10_0   T1  ENFERMEDAD   118   156
# 16     10_0   T1  ENFERMEDAD   159   186
# 17     10_0   T1  ENFERMEDAD   189   206
# 18     10_0   T1  ENFERMEDAD   239   272
# 19     10_0   T1  ENFERMEDAD   275   296
# 20     10_0   T1  ENFERMEDAD   299   336
# 21     11_0   T1  ENFERMEDAD    21    35
# 22     11_0   T1  ENFERMEDAD    95   118
# 23     11_0   T1  ENFERMEDAD   121   147
# 24     11_0   T1  ENFERMEDAD   250   270
# 25     11_0   T1  ENFERMEDAD   299   315
# 26     11_0   T1  ENFERMEDAD   341   348
# 27     11_0   T1  ENFERMEDAD   352   366
# 28     11_0   T1  ENFERMEDAD   394   421
# 29     11_0   T1  ENFERMEDAD   463   490
# 30     11_0   T1  ENFERMEDAD   509   532
# 31     11_0   T1  ENFERMEDAD   543   559
# 32     11_0   T1  ENFERMEDAD   597   612
# 33     11_0   T1  ENFERMEDAD   615   622
# 34     12_0   T1  ENFERMEDAD    22    36
# 35     12_0   T1  ENFERMEDAD    37    45
# 36     12_0   T1  ENFERMEDAD    49    57
# 37     12_0   T1  ENFERMEDAD    60    72
# 38     12_0   T1  ENFERMEDAD    90   102
# 39     12_0   T1  ENFERMEDAD   105   116
# 40     12_0   T1  ENFERMEDAD   146   156
# 41     12_0   T1  ENFERMEDAD   159   170
# 42     12_0   T1  ENFERMEDAD   173   179
# 43     12_0   T1  ENFERMEDAD   182   189
# 44     12_0   T1  ENFERMEDAD   211   232
# 45     13_0   T1  ENFERMEDAD     0    10
# 46     13_0   T1  ENFERMEDAD    14    30
# 47     13_0   T1  ENFERMEDAD    33    44
# 48     13_0   T1  ENFERMEDAD    47    58
# 49     14_0   T1  ENFERMEDAD     0    10
#
#                                       span           code semantic_rel
# 0                  дългогодишна хипертония  UMLS:C0745114        EXACT
# 1                               главоболие  UMLS:C0018681        EXACT
# 2                               сърцебиене  UMLS:C0030252        EXACT
# 3                               заморяване  UMLS:C0232292        EXACT
# 4              стягане в сърдечната област  UMLS:C0027497        EXACT
# 5                               сърцебиене  UMLS:C0042571        EXACT
# 6                                   гадене  UMLS:C0376358        EXACT
# 7                   карцином на простатата  UMLS:C0013217        EXACT
# 8                               главоболие  UMLS:C0018681        EXACT
# 9                            виене на свят  UMLS:C0042571        EXACT
# 10                             лесна умора  UMLS:C3553711        EXACT
# 11                        тежест в гърдите  UMLS:C0742339        EXACT
# 12                                   задух  UMLS:C0013404        EXACT
# 13                                   жажда  UMLS:C0039971        EXACT
# 14                 болки в дясно подребрие  UMLS:C2073338        EXACT
# 15  ирадииращи към кръста и дясната плешка  UMLS:C1960993        EXACT
# 16             с позиви за често уриниране  UMLS:C0042023        EXACT
# 17                       с парене и жежене  UMLS:C0858708        EXACT
# 18       подуване на лимфен възел на шията  UMLS:C4551446        EXACT
# 19                   болезнен при палпация  UMLS:C0234233        EXACT
# 20   образованието е оперативно отстранено  UMLS:C0578823        EXACT
# 21                          захарен диабет  UMLS:C0011849        EXACT
# 22                 диабетна полиневропатия  UMLS:C0271680        EXACT
# 23              тежка болкова симптоматика  UMLS:C0278140        EXACT
# 24                    стенокардни пристъпи  UMLS:C0020538        EXACT
# 25                        физически усилия  UMLS:C1854762        EXACT
# 26                                 стеноза  UMLS:C0031807        EXACT
# 27                          аортната клапа  UMLS:C0027051        EXACT
# 28             генерализирана остеоартроза  UMLS:C0003501        EXACT
# 29             коленни и тазобедрени стави  UMLS:C0678234        EXACT
# 30                 рецидивираща уролитиаза  UMLS:C0003501        EXACT
# 31                        уретеролитотомия  UMLS:C0409952        EXACT
# 32                         инсулинолечение  UMLS:C0728985        EXACT
# 33                                 чичовци  UMLS:C0022745        EXACT
# 34                          диагностициран  UMLS:C0011900        EXACT
# 35                                карцином  UMLS:C0998265        EXACT
# 36                                бял дроб  UMLS:C0024109        EXACT
# 37                            неоперабилен  UMLS:C0205187        EXACT
# 38                            химиотерапия  UMLS:C0013217        EXACT
# 39                             лъчелечение  UMLS:C1522449        EXACT
# 40                              главоболие  UMLS:C0018681        EXACT
# 41                             световъртеж  UMLS:C1069915        EXACT
# 42                                  нестаб  UMLS:C1444783        EXACT
# 43                                 походка  UMLS:C0016928        EXACT
# 44                   симптоматично лечение  UMLS:C5243901        EXACT
# 45                              оплаква се  UMLS:C3864418        EXACT
# 46                        лесно заморяване  UMLS:C0012833        EXACT
# 47                             световъртеж  UMLS:C1069915        EXACT
# 48                             шум в ушите  UMLS:C0235283        EXACT
# 49                              оплаква се  UMLS:C3864418        EXACT

# %%
df_pred_sap_nonum = df_pred_sap[~df_pred_sap['span'].str.contains("1|10|19|20|3|4|5|6|7|8|9|0")]

# %%
df_pred_sap_nonum.to_csv('vicuna_links/distemist_evaluation_library/toy-data/subtask-linking/bg_test_entities_sap_link_nonum.tsv', sep='\t', index=False)
